# %% [markdown]
# ## Variables

# %%
a = 5
a
# Out:
# 5

# %%
b = 'Abdullah'
b
a # Always print last vairbale that are used
# Out:
# 5

# %%
c = "Abdullah"
c
# Out:
# 'Abdullah'

# %%
print(a)
print(b)
# Out:
# 5
# Abdullah

# %%
x = str(5)    
y = int(5)    
z = float(5)

print(x)
print(y)
print(z)
# Out:
# 5
# 5
# 5.0

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
p = 'Muhammad '
P = 'Abdullah'

# %%
print(p)
print(P)
# Out:
# Muhammad
# Abdullah

# %%
print(p + '  ' + P)
# Out:
# Muhammad   Abdullah

# %%
print(a+y)
# Out:
# 10

# %%
print(a+b) # We cannot added  int and string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/m0/4t6ggwz51774ll_46v6qgz3h0000gn/T/ipykernel_1193/1083478837.py in <module>
# ----> 1 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
variable = 5
vari_able = 5
_variable = 5
Variable = 5
VARIABLE = 5
variable5 = 5

# %%
5variable = 5 # Variable Name cannot start from number
# Out:
#   File "/var/folders/m0/4t6ggwz51774ll_46v6qgz3h0000gn/T/ipykernel_1193/3299328541.py", line 1
#     5variable = 5
#      ^
# SyntaxError: invalid syntax

# %%
vari-able = 5 # Special Character Cannot be used as a variable name
# Out:
#   File "/var/folders/m0/4t6ggwz51774ll_46v6qgz3h0000gn/T/ipykernel_1193/225172146.py", line 1
#     vari-able = 5
#     ^
# SyntaxError: cannot assign to operator

# %%
var$able = 5
# Out:
#   File "/var/folders/m0/4t6ggwz51774ll_46v6qgz3h0000gn/T/ipykernel_1193/3601564415.py", line 1
#     var$able = 5
#        ^
# SyntaxError: invalid syntax

# %%
vari able =5 # Spaces cannot allow in variable
# Out:
#   File "/var/folders/m0/4t6ggwz51774ll_46v6qgz3h0000gn/T/ipykernel_1193/1683983009.py", line 1
#     vari able =5
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Datatypes

# %%
x1 = 5
x2 = "Abdullah"
x3 = 5.0
x4 = True
x5 = 6j
x6 = [1,2,3,4]
x7 = (1,2,3)
x8 = {1,2,3}
x9 = { "Name" : "Muhammad Abdullah" , "Father Name" : "Zulfiqar Ali"}
x10 = None

# %%
print(type(x1))
print(type(x2))
print(type(x3))
print(type(x4))
print(type(x5))
print(type(x6))
print(type(x7))
print(type(x8))
print(type(x9))
print(type(x10))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# <class 'complex'>
# <class 'list'>
# <class 'tuple'>
# <class 'set'>
# <class 'dict'>
# <class 'NoneType'>

# %% [markdown]
# ## Numbers

# %%
num1 = 5
num2 = -5
num3 = 5555555555555555555555555
num4 = 5555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555

# %%
import sys
print(sys.getsizeof(num4))
print(sys.getsizeof(num3))
print(sys.getsizeof(num2))
# Out:
# 76
# 36
# 28

# %%
print(type(num1))
print(type(num2))
print(type(num3))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
float1 = 5.0
float2 = -5.5
float3 = 123e4

# %%
print(type(float1))
print(type(float2))
print(type(float3))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
com1 = 0+1j
com2 = 5j
com3 = 1+2j
com4 = -5j

# %%
print(type(com1))
print(type(com2))
print(type(com3))
print(type(com4))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
int1 = int(float1)
int2 = int(com1) # We cannot convert complex type to integer type
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 int1 = int(float1)
# ----> 2 int2 = int(com1) # We cannot convert complex type to integer type
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
complex1 = complex(num1)

# %%
complex1
# Out:
# (5+0j)

# %% [markdown]
# ## Strings

# %%
X = '''Hello and Welcome to All of you at 
University of Engineering and Technology 
Under the Department of Computer Science parsuading degree BSAI'''
print(X)
# Out:
# Hello and Welcome to All of you at
# University of Engineering and Technology
# Under the Department of Computer Science parsuading degree BSAI

# %%
type(X)
# Out:
# str

# %%
Y = """Hello and Welcome to All of you at 
University of Engineering and Technology 
Under the Department of Computer Science parsuading degree BSAI"""
print(Y)
# Out:
# Hello and Welcome to All of you at
# University of Engineering and Technology
# Under the Department of Computer Science parsuading degree BSAI

# %%
Z = 'Abdullah'
print(Z[0])
print(Z[1])
print(Z[2])
print(Z[3])
print(Z[4])
print(Z[5])
print(Z[6])
print(Z[7])
# Out:
# A
# b
# d
# u
# l
# l
# a
# h

# %%
print(len(Z))
# Out:
# 8

# %%
print(len(X))
# Out:
# 141

# %%
print(Z.upper())
print(Z.title())
print(Z.replace("Abdullah", "Zulfiqar"))
# Out:
# ABDULLAH
# Abdullah
# Zulfiqar

# %%
name = input("Enter Name : ")

print(name)
# Out:
# Enter Name :  Muhammad Abdullah
# Muhammad Abdullah

# %%
name = "Abdullah"
score = 95

print(f" {name} score {score}")
# Out:
#  Abdullah score 95

# %%
name = input("Enter your full name :")
age = int(input("Enter your age :"))
course = input("Enter your Course Name : ")
fees = float(input("Enter your Course fees :"))

first_letter = name[0]
last_letter = name[-1]

discount = fees * 0.10
final_fees = fees - discount

print("\n-----------Student Report--------------")

print(f" Name : {name.title()}")
print(f" Age :  {age}")
print(f" Course Name : {course.upper()}")

print(f"\nFirst Letter : {name[0]}")
print(f"Last Letter : {name[-1]}")

print(f"\nOriginal Fees : pkr {fees}")
print(f"Discount : pkr {discount}")
print(f"Final Fees : pkr {final_fees}")

print("\n-------Data Types---------")
print(type(name))
print(type(age))
print(type(fees))

print(f"\nWelcome {name.title()}")
# Out:
# Enter your full name : Muhammad Abdullah
# Enter your age : 19
# Enter your Course Name :  Artificial Intelligence
# Enter your Course fees : 10000
# -----------Student Report--------------
#  Name : Muhammad Abdullah
#  Age :  19
#  Course Name : ARTIFICIAL INTELLIGENCE
#
# First Letter : M
# Last Letter : h
#
# Original Fees : pkr10000.0
# Discount : pkr1000.0
# Final Fees : pkr9000.0
#
# -------Data Types---------
# <class 'str'>
# <class 'int'>
# <class 'float'>
#
# Welcome Muhammad Abdullah
