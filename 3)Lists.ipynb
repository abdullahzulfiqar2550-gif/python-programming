# %%
list1 = [1,2,3,4,5]

# %%
list2 = ['one','two','three']

# %%
list3 = [True, False]

# %%
list4 = [5j , 1+2j]

# %%
print(type(list1))
print(type(list2))
print(type(list3))
print(type(list4))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
list1[0]
# Out:
# 1

# %%
list2[1]
# Out:
# 'two'

# %%
list3[1]
# Out:
# False

# %%
list4[0]
# Out:
# 5j

# %%
list1[-1]
# Out:
# 5

# %%
list1[-2]
# Out:
# 4

# %%
list1[1:4]
# Out:
# [2, 3, 4]

# %%
list1[:3]
# Out:
# [1, 2, 3]

# %%
list1[2:]
# Out:
# [3, 4, 5]

# %%
list1[-3:-1]
# Out:
# [3, 4]

# %%
list1.append(6)

# %%
list1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list2.append('six')

# %%
list2
# Out:
# ['one', 'two', 'three', 'six']

# %%
list2[3] = 'four'

# %%
list2
# Out:
# ['one', 'two', 'three', 'four']

# %%
list1.insert(0,0)

# %%
list1
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
list2.insert(0,'zero')

# %%
list2
# Out:
# ['zero', 'one', 'two', 'three', 'four']

# %%
list5 = [10,20,30,'hello','and','welcome',"to UET"]

# %%
list5
# Out:
# [10, 20, 30, 'hello', 'and', 'welcome', 'to UET']

# %%
list1.extend(list2)

# %%
list1
# Out:
# [0, 1, 2, 3, 4, 5, 6, 'zero', 'one', 'two', 'three', 'four']

# %%
list5.remove(10)

# %%
list5
# Out:
# [20, 30, 'hello', 'and', 'welcome', 'to UET']

# %%
list1.remove('zero')

# %%
list1
# Out:
# [0, 1, 2, 3, 4, 5, 6, 'one', 'two', 'three', 'four']

# %%
list1.pop()
# Out:
# 'four'

# %%
list1
# Out:
# [0, 1, 2, 3, 4, 5, 6, 'one', 'two', 'three']

# %%
list1.pop(0)
# Out:
# 0

# %%
list1.pop(1)
# Out:
# 2

# %%
list1
# Out:
# [1, 3, 4, 5, 6, 'one', 'two', 'three']

# %%
del list5

# %%
list5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 list5
#
# NameError: name 'list5' is not defined

# %%
list2.sort()

# %%
list2
# Out:
# ['four', 'one', 'three', 'two', 'zero']

# %%
list2.sort(reverse = True)

# %%
list2
# Out:
# ['zero', 'two', 'three', 'one', 'four']

# %%
list2.reverse()

# %%
list2
# Out:
# ['four', 'one', 'three', 'two', 'zero']

# %%
list4=list1.copy()

# %%
list4
# Out:
# [1, 2, 3, 4, 5, 6, 'one', 'two', 'three']

# %%
list5 = list(list4)

# %%
list5
# Out:
# [1, 2, 3, 4, 5, 6, 'one', 'two', 'three']

# %%
list5.clear()

# %%
list5
# Out:
# []

# %%
list5.append(1)

# %%
list5.append(1)

# %%
list5.append(1)

# %%
list5.append(1)

# %%
list5
# Out:
# [1, 1, 1, 1]
