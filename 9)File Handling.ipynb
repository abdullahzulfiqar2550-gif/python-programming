# %%
file1 = open("file1.txt", "x")

# %%
file1.write("Hello andd welcome dosto to AI Engineering Course")
file1.close()

# %%
f1 = open("file1.txt", "x") # error because file1.txt is already exist
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 f1 = open("file1.txt", "x") # error because file1.txt is already exist
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'file1.txt'

# %%
file1 = open("file1.txt", "r")
print(file1.read())
# Out:
# Hello andd welcome dosto to AI Engineering Course

# %%
file2 = open("file2.txt", "a")
file2.write("Append example")
file2.close()

# %%
file2 = open("file2.txt", "r")
print(file2.read())
# Out:
# Append example

# %%
file = open("file1.txt", "r")
print(file.read())
# Out:
# Hello andd welcome dosto to AI Engineering Course

# %%
file4 = open("file3.txt", "w")
file4.write("write mode open example")
file4.close()

# %%
file = open("file3.txt", "r")
print(file.read())
# Out:
# write mode open example

# %%
file4 = open("file3.txt", "w")
file4.write("write mode overwrite example")
file4.close()

# %%
file = open("file3.txt", "r")
print(file.read())
# Out:
# write mode overwrite example

# %%
file4 = open("file3.txt", "a")
file4.write("+++append mode example")
file4.close()

# %%
file = open("file3.txt", "r")
print(file.read())
# Out:
# write mode overwrite example+++append mode example

# %%
import os
os.remove("file1.txt")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[14], line 2
#       1 import os
# ----> 2 os.remove("file1.txt")
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'file1.txt'

# %%
file = open("file3.txt", "w")
file.write("specific location example")
file.close()

# %%
file = open(r"C:\Users\Abdul\OneDrive\Documents\Python\file2.txt", "r")
print(file.read())
# Out:
# Append example

# %%
os.remove("/Users/shridharmankar/Desktop/file5.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 os.remove("/Users/shridharmankar/Desktop/file5.txt")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/Users/shridharmankar/Desktop/file5.txt'
