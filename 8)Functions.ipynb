# %%
def function1():
  print("Hello and Welcome Dosto to UET")

# %%
function1()
# Out:
# Hello and Welcome Dosto to UET

# %%
def function2(plus):
  print("Hello and Welcome Dosto",plus)

function2('to AI Engineering Course')
# Out:
# Hello and Welcome Dosto to AI Engineering Course

# %%
def function2(plus):
  print("Hello and Welcome Dosto " + plus)

function2('to AI Engineering Course')
# Out:
# Hello and Welcome Dosto to AI Engineering Course

# %%
def name(fname,lname):
  print(fname + " " + lname)

name('Muhammad','Abdullah')
# Out:
# Muhammad Abdullah

# %%
name('Muhammad','Samran')
# Out:
# Muhammad Samran

# %%
def function2(*plus):
  print("Hello and Welcome Dosto", plus[0],plus[1],plus[2] )

function2('to UET Lahore','and','to AI Engineering Course')
# Out:
# Hello and Welcome Dosto to UET Lahore and to AI Engineering Course

# %%
def name1(lname,fname):
  print(fname + " " + lname)

name1(fname = 'Muhammad',lname = 'Abdullah')
# Out:
# Muhammad Abdullah

# %%
def name2(**student):
  print(student['fname'] + " " + student['lname'])

name2(fname = 'Muhammad',lname = 'Abdullah')
# Out:
# Muhammad Abdullah

# %%
def name3(**students):
  print(students['s1'],students['s2'],students['s3'])

name3(s2 = 'Abdullah',s1 = 'Muhammad',s3 = 'Zulfiqar')
# Out:
# Muhammad Abdullah Zulfiqar

# %%
def function2(plus = 'to AI Engineering Course'):
  print("Hello and Welcome Dosto",plus)

function2('to data science Course')
function2()
# Out:
# Hello and Welcome Dosto to data science Course
# Hello and Welcome Dosto to AI Engineering Course

# %%
def sum_fun(a,b):
  c = a+b
  return c

sum_fun(1,2)
# Out:
# 3

# %%
sum_fun(2,3)
# Out:
# 5

# %%
square = lambda x: x * x * x
print(square(6))
# Out:
# 216

# %%
add = lambda a, b: a + b
print(add(10, 20))
# Out:
# 30

# %%
numbers = [1, 2, 3]
squares = list(map(lambda x: x**2, numbers))
print(squares)
# Out:
# [1, 4, 9]

# %%
def countdown(n):
    if n == 0:
        return
    print(n)
    countdown(n - 1)

countdown(3)
# Out:
# 3
# 2
# 1

# %%
def total(n):
    if n == 0:
        return 0
    return n + total(n - 1)

print(total(5))
# Out:
# 15
