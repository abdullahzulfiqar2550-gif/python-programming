# %%
def function1():ss
  print("Hello and Welcome Dosto to UET Lahore")

# %%
function1()
# Out:
# Hello and Welcome Dosto to UET Lahore

# %%
def function2(plus):
  print("Hello and Welcome Dosto ",plus)

function2('to AI course')
# Out:
# Hello and Welcome Dosto  to AI course

# %%
def function2(plus):
  print("Hello and Welcome Dosto " + plus)

function2('to AI Engineering Course')
# Out:
# Hello and Welcome Dosto to AI Engineering Course

# %%
def name(fname,lname):
  print(fname + " " + lname)

name('Muhammad','Abdullah')
# Out:
# Muhammad Abdullah

# %%
name('Muhammad ','Samran')
# Out:
# Muhammad  Samran

# %%
def function2(*plus):
  print("Hello and Welcome Dosto", plus[0],plus[1],plus[2] )

function2('to UET Lahore','and','to AI Engineering Course')
# Out:
# Hello and Welcome Dosto to UET Lahore and to AI Engineering Course

# %%
def name1(lname,fname):
  print(fname + " " + lname)

name1(fname = 'Muhammad',lname = 'Abdullah')
# Out:
# Muhammad Abdullah

# %%
def name2(**student):
  print(student['fname'] + " " + student['lname'])

name2(fname = 'Muhammad',lname = 'Abdullah')
# Out:
# Muhammad Abdullah

# %%
def name3(**students):
  print(students['s1'],students['s2'],students['s3'])

name3(s2 = 'Abdullah',s1 = 'Muhammad',s3 = 'Zulfiqar')
# Out:
# Muhammad Abdullah Zulfiqar

# %%
def function2(plus = 'to AI Engineering'):
  print("Hello and Welcome Dosto",plus)

function2('to data Science')
function2()
# Out:
# Hello and Welcome Dosto to data Science
# Hello and Welcome Dosto to AI Engineering

# %%
def sum_fun(a,b):
  c = a+b
  return c

sum_fun(1,2)
# Out:
# 3

# %%
sum_fun(2,3)
# Out:
# 5
