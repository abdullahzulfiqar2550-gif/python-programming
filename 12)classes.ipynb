# %%
class class1:
    v1 = "Muhammad"
    v2 = 1

obj1 = class1()
print(obj1)
print(obj1.v1)
print(obj1.v2)
# Out:
# ...
# Muhammad
# 1

# %%
obj2 = class1()
print(obj2.v1)
obj2.v1 = "Ahmad"
print(obj2.v1)
# Out:
# Muhammad
# Ahmad

# %%
class class2:
    name = "Muhammad"
    roll_no = 1

    def abc(self):
        print("name-->",self.name)

obj11 = class2()
obj11.abc()
obj11.name = "Samran"
obj11.abc()
# Out:
# name--> Muhammad
# name--> Samran

# %%
class class3:
    def __init__(self,name):
        self.name = name

    roll_no = 1

    def abc(self):
        print("name-->",self.name)

obj111 = class3("Bilal")
print(obj111.name)
obj111.abc()
# Out:
# Bilal
# name--> Bilal
